# %% [markdown]
# <a href="https://colab.research.google.com/github/hqu/age_vs_height/blob/main/scatter_plot_age_vs_height.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualize the relationship between age and height

# %% [markdown]
# ## Step 1: Import the dataset Howell1 into a pandas dataframe
# https://github.com/rmcelreath/rethinking/blob/master/data/Howell1.csv

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Set values for variables for age for children cutoff and colors for gender
age_cutoff_children = 19
color_female = 'red'
color_male = 'blue'

# %%
df = pd.read_csv('https://raw.githubusercontent.com/rmcelreath/rethinking/master/data/Howell1.csv', sep=';')

# %%
df
# Out:
#       height     weight   age  male
# 0    151.765  47.825606  63.0     1
# 1    139.700  36.485807  63.0     0
# 2    136.525  31.864838  65.0     0
# 3    156.845  53.041914  41.0     1
# 4    145.415  41.276872  51.0     0
# ..       ...        ...   ...   ...
# 539  145.415  31.127751  17.0     1
# 540  162.560  52.163080  31.0     1
# 541  156.210  54.062497  21.0     0
# 542   71.120   8.051258   0.0     1
# 543  158.750  52.531624  68.0     1
#
# [544 rows x 4 columns]

# %% [markdown]
# ## Step 2: Extract the list of ages and heights from the dataframe into 2 lists (age_list and height_list)

# %%
age_list = df["age"].tolist()
height_list = df["height"].tolist()

# %%
print(age_list)
# Out:
# [63.0, 63.0, 65.0, 41.0, 51.0, 35.0, 32.0, 27.0, 19.0, 54.0, 47.0, 66.0, 73.0, 20.0, 65.3, 36.0, 44.0, 31.0, 12.0, 8.0, 6.5, 39.0, 29.0, 13.0, 7.0, 56.0, 45.0, 19.0, 17.0, 16.0, 11.0, 29.0, 30.0, 24.0, 35.0, 33.0, 27.0, 32.0, 36.0, 24.0, 30.0, 24.0, 52.0, 42.0, 19.0, 17.0, 8.0, 12.0, 5.0, 55.0, 43.0, 20.0, 18.0, 13.0, 9.0, 5.0, 42.0, 44.0, 60.0, 20.0, 37.0, 50.0, 50.0, 31.0, 25.0, 23.0, 52.0, 79.3, 35.0, 27.0, 13.0, 14.0, 38.0, 39.0, 12.0, 30.0, 24.0, 0.599999999999909, 51.0, 46.0, 17.0, 12.0, 22.0, 29.0, 38.0, 30.0, 6.0, 45.0, 47.0, 79.0, 45.0, 54.0, 31.0, 23.0, 9.0, 41.0, 23.0, 36.0, 5.0, 30.0, 12.0, 34.0, 44.0, 43.0, 73.3, 38.0, 43.0, 33.0, 16.0, 11.0, 6.0, 35.0, 29.0, 12.0, 9.0, 7.59999999999991, 58.0, 53.0, 51.0, 48.0, 29.0, 41.0, 81.75, 1.0, 35.0, 46.0, 5.0, 29.0, 42.0, 27.0, 8.0, 6.0, 22.0, 43.0, 53.0, 43.0, 41.0, 50.0, 15.0, 33.0, 3.0, 62.0, 49.0, 17.0, 12.0, 22.0, 29.0, 8.0, 5.0, 33.0, 34.0, 12.0, 7.0, 42.0, 40.0, 27.0, 3.0, 25.0, 29.0, 45.0, 26.0, 45.0, 45.0, 11.0, 85.59999
# ...

# %%
print(height_list)
# Out:
# [151.765, 139.7, 136.525, 156.845, 145.415, 163.83, 149.225, 168.91, 147.955, 165.1, 154.305, 151.13, 144.78, 149.9, 150.495, 163.195, 157.48, 143.9418, 121.92, 105.41, 86.36, 161.29, 156.21, 129.54, 109.22, 146.4, 148.59, 147.32, 137.16, 125.73, 114.3, 147.955, 161.925, 146.05, 146.05, 152.7048, 142.875, 142.875, 147.955, 160.655, 151.765, 162.8648, 171.45, 147.32, 147.955, 144.78, 121.92, 128.905, 97.79, 154.305, 143.51, 146.7, 157.48, 127.0, 110.49, 97.79, 165.735, 152.4, 141.605, 158.8, 155.575, 164.465, 151.765, 161.29, 154.305, 145.415, 145.415, 152.4, 163.83, 144.145, 129.54, 129.54, 153.67, 142.875, 146.05, 167.005, 158.4198, 91.44, 165.735, 149.86, 147.955, 137.795, 154.94, 160.9598, 161.925, 147.955, 113.665, 159.385, 148.59, 136.525, 158.115, 144.78, 156.845, 179.07, 118.745, 170.18, 146.05, 147.32, 113.03, 162.56, 133.985, 152.4, 160.02, 149.86, 142.875, 167.005, 159.385, 154.94, 148.59, 111.125, 111.76, 162.56, 152.4, 124.46, 111.76, 86.36, 170.18, 146.05, 159.385, 151.1
# ...

# %% [markdown]
# ## Step 3: Graph the scatterplot

# %%
plt.scatter(age_list, height_list)
plt.show()

# %% [markdown]
# ## Step 4: Filter out everyone over the age of a cutoff age to separate children from adults

# %%
filtered_df_children = df[df['age'] < age_cutoff_children]
filtered_df_adults = df[df['age'] >= age_cutoff_children]

# %%
child_age_list_filtered = filtered_df_children["age"].tolist()
child_height_list_filtered = filtered_df_children["height"].tolist()

adult_age_list_filtered = filtered_df_adults["age"].tolist()
adult_height_list_filtered = filtered_df_adults["height"].tolist()

# %%
age_list_filtered = filtered_df_children["age"].tolist()
height_list_filtered = filtered_df_children["height"].tolist()

# %%
plt.scatter(age_list_filtered, height_list_filtered)
plt.show()

# %%
fig, ax = plt.subplots()
plt.

# %%
col = filtered_df_children.male.map({0:color_female, 1:color_male})
filtered_df_children.plot.scatter(x='age', y='height', c=col)
plt.show()

# %%
filtered_df_adult = df[df['age'] >= age_cutoff_children]
age_list_filtered_adult = filtered_df_adult["age"].tolist()
height_list_filtered_adult = filtered_df_adult["height"].tolist()

# %%
plt.scatter(age_list_filtered_adult, height_list_filtered_adult)
plt.show()

# %%
col = filtered_df_adult.male.map({0:color_female, 1:color_male})
filtered_df_adult.plot.scatter(x='age', y='height', c=col)
plt.legend(["male", "female"])

# %%
def calculate_mean_height(df):
    return df["height"].mean()
calculate_mean_height(df)
# Out:
# 138.2635963235294

# %%
def calculate_mean_height_by_age(df):
    return df.groupby("age")["height"].mean()

calculate_mean_height_by_age(df)
# Out:
# age
# 0.0      63.326818
# 0.6      91.440000
# 1.0      72.548173
# 2.0      90.593333
# 3.0      88.412918
#            ...
# 82.0    149.225000
# 83.0    159.385000
# 83.4    151.765000
# 85.6    140.970000
# 88.0    153.035000
# Name: height, Length: 99, dtype: float64

# %%
#visualizations of the mean height by age
calculate_mean_height_by_age(df).plot()
plt.show()

# %%
#visualize individual data points  
plt.scatter(age_list, height_list)
plt.show()

# %%
# Out:
# <AxesSubplot:xlabel='age', ylabel='height'>

# %%
sns.regplot(x='age', y='height', data=filtered_df_children, color='orange' , scatter_kws={'alpha':0.3}, label='Children')
sns.regplot(x='age', y='height', data=filtered_df_adult, color='blue' , scatter_kws={'alpha':0.3}, label='Adults')
plt.title('Height vs Age')
sns.despine()
plt.legend()

# %%
#graph bar chart of mean height by age
calculate_mean_height_by_age(df).plot.bar()
plt.show()

# %%
# graph children and adults separately
calculate_mean_height_by_age(filtered_df_children).plot.bar()
plt.show()
#graph adults
calculate_mean_height_by_age(filtered_df_adult).plot.bar()
plt.show()

# %% [markdown]
# ## END
